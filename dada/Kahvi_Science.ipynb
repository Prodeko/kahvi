# %% [markdown]
# # KAHVISHITTII!

# %%
#imports

import pandas as pd
import numpy as np
from PIL import Image

# %%
im = Image.open("dummy.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x107F72550>
